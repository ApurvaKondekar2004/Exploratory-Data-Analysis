# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("heart (1).csv")
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df.describe(include='object')
# Out:
#         Sex ChestPainType RestingECG ExerciseAngina ST_Slope
# count   918           918        918            918      918
# unique    2             4          3              2        3
# top       M           ASY     Normal              N     Flat
# freq    725           496        552            547      460

# %%
df["RestingBP"].min()
# Out:
# 0

# %%
df["RestingBP"].max()
# Out:
# 200

# %%
sns.distplot(df["RestingBP"])
# Out:
# C:\Users\Apurva\AppData\Local\Temp\ipykernel_19504\2807266475.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["RestingBP"])
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='RestingBP', ylabel='Density'>

# %%
df["RestingBP"]=df["RestingBP"].replace(0,df["RestingBP"].mean())

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.540737   198.799564    0.233115  136.809368
# std      9.432617   17.989932   109.384145    0.423046   25.460334
# min     28.000000   80.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
sns.distplot(df["Cholesterol"])
# Out:
# C:\Users\Apurva\AppData\Local\Temp\ipykernel_19504\3991774932.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Cholesterol"])
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Cholesterol', ylabel='Density'>

# %%
df["Cholesterol"]=df["Cholesterol"].replace(0,df["Cholesterol"].mean())

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.540737   236.047413    0.233115  136.809368
# std      9.432617   17.989932    56.240952    0.423046   25.460334
# min     28.000000   80.000000    85.000000    0.000000   60.000000
# 25%     47.000000  120.000000   198.799564    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
sns.countplot(x='Sex',hue='HeartDisease',data=df)
plt.title("Individuals having heart disease with respect to gender")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()
#Males suffer more than females
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 sns.countplot(x='Sex',hue='HeartDisease',data=df)
#       2 plt.title("Individuals having heart disease with respect to gender")
#       3 plt.xlabel("Gender")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# ...

# %%
df.groupby("ChestPainType").size().plot(kind='pie',autopct="%0.2f")
# Out:
# <Axes: >

# %%
df.groupby("RestingECG").size().plot(kind='pie',autopct="%0.2f")
# Out:
# <Axes: >

# %%
df.groupby("ExerciseAngina").size().plot(kind='pie',autopct="%0.2f")
# Out:
# <Axes: >

# %%
df.groupby("ST_Slope").size().plot(kind='pie',autopct="%0.2f")
# Out:
# <Axes: >

# %%
sns.displot(df,x="Age",hue="HeartDisease")
#People with age greater than 60 yrs usually suffer from it
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
sns.violinplot(x=df["Sex"],y=df["HeartDisease"])
#the wider section in the male at 1 indicates many suffer from this disease as compared to females and the white dot represents the median
# Out:
# <Axes: xlabel='Sex', ylabel='HeartDisease'>

# %%
sns.violinplot(x=df["Sex"],y=df["Cholesterol"])
#The wider spread show many have cholestrol 200 as compared to other and the high peaks represent outliers
# Out:
# <Axes: xlabel='Sex', ylabel='Cholesterol'>

# %%
# One-hot encode the 'Sex' and 'ChestPainType' columns
df = pd.get_dummies(df, columns=['Sex', 'ChestPainType'], drop_first=True)

# %%
df
# Out:
#      Age  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR ExerciseAngina  \
# 0     40      140.0        289.0          0     Normal    172              N
# 1     49      160.0        180.0          0     Normal    156              N
# 2     37      130.0        283.0          0         ST     98              N
# 3     48      138.0        214.0          0     Normal    108              Y
# 4     54      150.0        195.0          0     Normal    122              N
# ..   ...        ...          ...        ...        ...    ...            ...
# 913   45      110.0        264.0          0     Normal    132              N
# 914   68      144.0        193.0          1     Normal    141              N
# 915   57      130.0        131.0          0     Normal    115              Y
# 916   57      130.0        236.0          0        LVH    174              N
# 917   38      138.0        175.0          0     Normal    173              N
#
# ...

# %%
#Label Encoding
from sklearn.preprocessing import LabelEncoder

# Example: Encoding 'RestingECG' as it might have ordinal nature
label_encoder = LabelEncoder()

df['RestingECG'] = label_encoder.fit_transform(df['RestingECG'])

# %%
df["RestingECG"].unique()
# Out:
# array([1, 2, 0])

# %%
plt.figure(figsize=(10,6))
df.plot(kind='box', subplots=True)
plt.xticks(rotation=90)
# Out:
# (array([1]), [Text(1, 0, 'HeartDisease')])

# %%
sns.boxplot(df["Cholesterol"])
# Out:
# <Axes: >

# %%
#Define a function to remove outliers based on IQR
def remove_outliers(df, x):
    Q1 = df["Cholesterol"].quantile(0.25)
    Q3 = df["Cholesterol"].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df["Cholesterol"] >= lower_bound) & (df["Cholesterol"] <= upper_bound)]

# Apply outlier removal on 'Cholesterol'
df = remove_outliers(df, 'Cholesterol')

# %%
sns.boxplot(df["Cholesterol"])
# Out:
# <Axes: >

# %%
def remove_outliers(df, x):
    Q1 = df["RestingBP"].quantile(0.25)
    Q3 = df["RestingBP"].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df["RestingBP"] >= lower_bound) & (df["RestingBP"] <= upper_bound)]

# Apply outlier removal on 'Cholesterol'
df = remove_outliers(df, 'RestingBP')
sns.boxplot(df["RestingBP"])
# Out:
# <Axes: >

# %%
def remove_outliers(df, x):
    Q1 = df["Oldpeak"].quantile(0.25)
    Q3 = df["Oldpeak"].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df["Oldpeak"] >= lower_bound) & (df["Oldpeak"] <= upper_bound)]

# Apply outlier removal on 'Cholesterol'
df = remove_outliers(df, 'Oldpeak')
sns.boxplot(df["Oldpeak"])
# Out:
# <Axes: >
